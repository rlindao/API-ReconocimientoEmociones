# %%
import numpy as np
import argparse
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
mode = 'train'

# %%
def plot_model_history(model_history):
    """
    Plot Accuracy and Loss curves given the model_history
    """
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    fig.savefig('plot.png')
    plt.show()

# Define data generators
train_dir = '/content/drive/My Drive/Reconocimiento De Emociones/src/data/train'
val_dir = '/content/drive/My Drive/Reconocimiento De Emociones/src/data/test'

num_train = 28709
num_val = 7178
batch_size = 64
num_epoch = 50

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# If you want to train the same model or try other models, go for this
if mode == "train":
    model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
    model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=num_train // batch_size,
            epochs=num_epoch,
            validation_data=validation_generator,
            validation_steps=num_val // batch_size)
    plot_model_history(model_info)
    model.save_weights('model.h5')
# Out:
# Epoch 1/50
# 448/448 [==============================] - 15266s 34s/step - loss: 1.7573 - accuracy: 0.2846 - val_loss: 1.6303 - val_accuracy: 0.3697
# Epoch 2/50
# 448/448 [==============================] - 63s 140ms/step - loss: 1.5934 - accuracy: 0.3803 - val_loss: 1.5043 - val_accuracy: 0.4326
# Epoch 3/50
# 448/448 [==============================] - 60s 134ms/step - loss: 1.5014 - accuracy: 0.4207 - val_loss: 1.4343 - val_accuracy: 0.4503
# Epoch 4/50
# 448/448 [==============================] - 60s 133ms/step - loss: 1.4372 - accuracy: 0.4533 - val_loss: 1.3815 - val_accuracy: 0.4798
# Epoch 5/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.3825 - accuracy: 0.4728 - val_loss: 1.3443 - val_accuracy: 0.4888
# Epoch 6/50
# 448/448 [==============================] - 60s 135ms/step - loss: 1.3351 - accuracy: 0.4939 - val_loss: 1.3071 - val_accuracy: 0.5014
# Epoch 7/50
# 448/448 [==============================] - 60s 135ms/step - loss: 1.2897 - accuracy: 0.5121 - val_loss: 1.2616 - val_accuracy: 0.5225
# Epoch 8/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.2601 - accuracy: 0.5236 - val_loss: 1.2441 - val_accuracy: 0.5264
# Epoch 9/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.2280 - accuracy: 0.5387 - val_loss: 1.2492 - val_accuracy: 0.5241
# Epoch 10/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.1971 - accuracy: 0.5497 - val_loss: 1.1987 - val_accuracy: 0.5465
# Epoch 11/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.1701 - accuracy: 0.5587 - val_loss: 1.1852 - val_accuracy: 0.5487
# Epoch 12/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.1431 - accuracy: 0.5733 - val_loss: 1.1606 - val_accuracy: 0.5611
# Epoch 13/50
# 448/448 [==============================] - 60s 135ms/step - loss: 1.1161 - accuracy: 0.5834 - val_loss: 1.1480 - val_accuracy: 0.5700
# Epoch 14/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.0984 - accuracy: 0.5884 - val_loss: 1.1457 - val_accuracy: 0.5717
# Epoch 15/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.0701 - accuracy: 0.5990 - val_loss: 1.1244 - val_accuracy: 0.5805
# Epoch 16/50
# 448/448 [==============================] - 58s 131ms/step - loss: 1.0501 - accuracy: 0.6087 - val_loss: 1.1137 - val_accuracy: 0.5876
# Epoch 17/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.0278 - accuracy: 0.6175 - val_loss: 1.1043 - val_accuracy: 0.5869
# Epoch 18/50
# 448/448 [==============================] - 60s 134ms/step - loss: 1.0089 - accuracy: 0.6271 - val_loss: 1.1102 - val_accuracy: 0.5862
# Epoch 19/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.9823 - accuracy: 0.6351 - val_loss: 1.0937 - val_accuracy: 0.5970
# Epoch 20/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.9620 - accuracy: 0.6457 - val_loss: 1.0939 - val_accuracy: 0.5939
# Epoch 21/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9358 - accuracy: 0.6519 - val_loss: 1.0830 - val_accuracy: 0.6004
# Epoch 22/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.9142 - accuracy: 0.6649 - val_loss: 1.0801 - val_accuracy: 0.6021
# Epoch 23/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.8938 - accuracy: 0.6711 - val_loss: 1.0723 - val_accuracy: 0.6105
# Epoch 24/50
# 448/448 [==============================] - 57s 128ms/step - loss: 0.8718 - accuracy: 0.6792 - val_loss: 1.0898 - val_accuracy: 0.6016
# Epoch 25/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.8523 - accuracy: 0.6889 - val_loss: 1.0749 - val_accuracy: 0.6140
# Epoch 26/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.8304 - accuracy: 0.6964 - val_loss: 1.0718 - val_accuracy: 0.6077
# Epoch 27/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.8065 - accuracy: 0.7053 - val_loss: 1.0688 - val_accuracy: 0.6122
# Epoch 28/50
# 448/448 [==============================] - 60s 134ms/step - loss: 0.7810 - accuracy: 0.7116 - val_loss: 1.0699 - val_accuracy: 0.6173
# Epoch 29/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.7598 - accuracy: 0.7210 - val_loss: 1.0683 - val_accuracy: 0.6158
# Epoch 30/50
# 448/448 [==============================] - 57s 127ms/step - loss: 0.7379 - accuracy: 0.7313 - val_loss: 1.0758 - val_accuracy: 0.6140
# Epoch 31/50
# 448/448 [==============================] - 56s 126ms/step - loss: 0.7212 - accuracy: 0.7391 - val_loss: 1.0750 - val_accuracy: 0.6165
# Epoch 32/50
# 448/448 [==============================] - 57s 128ms/step - loss: 0.6992 - accuracy: 0.7451 - val_loss: 1.0859 - val_accuracy: 0.6094
# Epoch 33/50
# 448/448 [==============================] - 57s 127ms/step - loss: 0.6781 - accuracy: 0.7533 - val_loss: 1.0793 - val_accuracy: 0.6210
# Epoch 34/50
# 448/448 [==============================] - 60s 133ms/step - loss: 0.6468 - accuracy: 0.7659 - val_loss: 1.0815 - val_accuracy: 0.6182
# Epoch 35/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.6326 - accuracy: 0.7715 - val_loss: 1.0970 - val_accuracy: 0.6223
# Epoch 36/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.6214 - accuracy: 0.7751 - val_loss: 1.0957 - val_accuracy: 0.6219
# Epoch 37/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.6054 - accuracy: 0.7772 - val_loss: 1.0940 - val_accuracy: 0.6229
# Epoch 38/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.5884 - accuracy: 0.7861 - val_loss: 1.1005 - val_accuracy: 0.6200
# Epoch 39/50
# 448/448 [==============================] - 60s 134ms/step - loss: 0.5580 - accuracy: 0.7994 - val_loss: 1.1156 - val_accuracy: 0.6268
# Epoch 40/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.5471 - accuracy: 0.8007 - val_loss: 1.1210 - val_accuracy: 0.6223
# Epoch 41/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.5290 - accuracy: 0.8096 - val_loss: 1.1128 - val_accuracy: 0.6242
# Epoch 42/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.5069 - accuracy: 0.8198 - val_loss: 1.1288 - val_accuracy: 0.6198
# Epoch 43/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.4967 - accuracy: 0.8202 - val_loss: 1.1315 - val_accuracy: 0.6251
# Epoch 44/50
# 448/448 [==============================] - 61s 137ms/step - loss: 0.4820 - accuracy: 0.8264 - val_loss: 1.1380 - val_accuracy: 0.6250
# Epoch 45/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.4663 - accuracy: 0.8308 - val_loss: 1.1323 - val_accuracy: 0.6215
# Epoch 46/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.4549 - accuracy: 0.8368 - val_loss: 1.1497 - val_accuracy: 0.6258
# Epoch 47/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.4408 - accuracy: 0.8428 - val_loss: 1.1752 - val_accuracy: 0.6268
# Epoch 48/50
# 448/448 [==============================] - 59s 133ms/step - loss: 0.4291 - accuracy: 0.8468 - val_loss: 1.1625 - val_accuracy: 0.6214
# Epoch 49/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.4194 - accuracy: 0.8482 - val_loss: 1.1979 - val_accuracy: 0.6235
# Epoch 50/50
# 448/448 [==============================] - 61s 135ms/step - loss: 0.3996 - accuracy: 0.8558 - val_loss: 1.2106 - val_accuracy: 0.6272
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
